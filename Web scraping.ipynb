# %%
! pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\shamsiya s a\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\shamsiya s a\anaconda3\lib\site-packages (from beautifulsoup4) (2.3.1)

# %%
! pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\shamsiya s a\anaconda3\lib\site-packages (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shamsiya s a\anaconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\shamsiya s a\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\shamsiya s a\anaconda3\lib\site-packages (from requests) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shamsiya s a\anaconda3\lib\site-packages (from requests) (3.3)

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests

# %%
try:
        
    page=requests.get('https://apps3.txdot.gov/apps-cq/project_tracker/')                            
    
except Exception as e:                                   
    error_type, error_obj, error_info = sys.exc_info()      
    print ('ERROR FOR LINK:',url)                          
    print (error_type, 'Line:', error_info.tb_lineno)     
                                                 
time.sleep(2)   
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('td',attrs={'class':'SummaryTableLeft'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="initial-scale=1, maximum-scale=1,user-scalable=no" name="viewport"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.3.1/jquery.min.js"></script>
# <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js"></script>
# <script src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.js"></script>
# <title>Project Tracker</title>
# <link href="//js.arcgis.com/3.29/dojo/resources/dojo.css" rel="stylesheet" type="text/css"/>
# <link href="//js.arcgis.com/3.29/dijit/themes/tundra/tundra.css" rel="stylesheet" type="text/css"/>
# <link href="CSS/StyleSheet.css" rel="stylesheet" type="text/css"/>
# <link href="Styles/ohp_site.css" rel="stylesheet" type="text/css"/>
# <link href="https://js.arcgis.com/3.29/esri/css/esri.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
# <link href="https://ajax.googleapis.com/ajax/libs/jqueryui/1.12.1/themes/smoothness/jquery-ui.css" rel="stylesheet">
# <script src="https://js.arcgis.com/3.29/"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/bootstrap-datepicker/1.3.0/js/bootstrap-datepicker.min.js"></script>
# <link href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap-datepicker/1.3.0/css/datepicker3.min.css" rel="stylesheet"/>
# <link href="css/SingleWing.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#         dojoConfig = { parseOnLoad: true }
#
#         /*Browser Detection*/
#         function GetBrowser() {
#             var ua = navigator.userAgent, tem,
#                 M = ua.match(/(opera|chrome|safari|firefox|msie|trident(?=\/))\/?\s*([\d\.]+)/i) || [];
#             if (/trident/i.test(M[1])) {
#                 tem = /\brv[ :]+(\d+(\.\d+)?)/g.exec(ua) || [];
#                 return 'MSIE ' + (tem[1] || '');
#             }
#             M = M[2] ? [M[1], M[2]] : [navigator.appName, navigator.appVersion, '-?'];
#             if ((tem = ua.match(/version\/([\.\d]+)/i)) != null) M[2] = tem[1];
#             return M.join(' ');
#         }
#         Browser = GetBrowser().split(" ")[0];
#         BrowserVersion = GetBrowser().split(" ")[1];
# 		//alert(BrowserVersion + "  " + Browser + "  " + GetBrowser().split(" ")[2] + " ::" + GetBrowser())
# 		//alert(navigator.appVersion.split(" ")[4]);
# 		    is_iPad = navigator.userAgent.match(/iPad/i) != null;
#
#         if ((Browser == "MSIE" && BrowserVersion == "11.0")) {
#           document.write('<link id=IeCSS rel="stylesheet" type="text/css" href="css/IE11.css" />');
#           if (window.innerWidth < 1250) {
#             document.write('<link id=IeCSS rel="stylesheet" type="text/css" href="css/IE11_1200.css" />');
#           }
#         }
#         if ((Browser == "MSIE" && BrowserVersion == "10.0")) {
#           document.write('<link rel="stylesheet" type="text/css" href="css/IE10.css" />');
#         }
#
#         if (Browser == "MSIE" && parseInt(BrowserVersion) < 10) {
#             var msg = "*****   Attention Internet Explorer User  ***** \n\n"
#             msg = msg + "Please use IE 10 or IE 11 OR ensure that compatibility mode is not enabled for this site... \n\n"
#
#             msg = msg + "To check compatibilty settings do the following:\n\n"
#             msg = msg + "Hit F10-->Tools-->Compatibility View Settings\n\n"
#             msg = msg + "Alternatively, please consider using Chrome or Firefox"
#             alert(msg)
#         }
#
#         if (Browser == "Chrome") {
#           document.write('<link id="ChromeCSS" rel="stylesheet" type="text/css" href="CSS/Chrome.css" />');
#           if (window.innerWidth < 1200) {
#             document.write('<link id="ChromeCSS" rel="stylesheet" type="text/css" href="CSS/Chrome_1200.css" />');
#           }
#         }
#         if (Browser == "Safari") {
#           if (is_iPad) {
#             if (window.orientation == 0) {
#               //alert('Portrait Mode, Home Button bottom');
#               document.write('<link id="IPad" rel="stylesheet" type="text/css" href="CSS/IPAD_portrait.css" />');
#             } else if (window.orientation == 90) {
#               document.write('<link id="IPad"  rel="stylesheet" type="text/css" href="CSS/IPAD_Landscape.css" />');
#               //alert('Landscape Mode, Home Button right');
#             } else if (window.orientation == -90) {
#               //alert('Landscape Mode, Home Button left');
#               document.write('<link id="IPad"  rel="stylesheet" type="text/css" href="CSS/IPAD_Landscape.css" />');
#             } else if (window.orientation == 180) {
#               //alert('Portrait Mode, Home Button top');
#               document.write('<link  id="IPad" rel="stylesheet" type="text/css" href="CSS/IPAD_portrait.css" />');
#             }
#           } else {
#             document.write('<link rel="stylesheet" type="text/css" href="CSS/Safari.css" />');
#           }
#         }
#
#         if (Browser == "Firefox") {
#             document.write('<link rel="stylesheet" type="text/css" href="CSS/Firefox.css" />');
#         }
#     </script>
# <script type="text/javascript">
#
#     (function(i,s,o,g,r,a,m){
#       i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m) })
#         (window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#         ga('create', 'UA-26874019-3', 'auto', {'allowLinker': true});
#         ga('require', 'linker');
#         ga('linker:autoLink', ['txdot.com', 'publiccm.txdot.gov', 'careers.txdot.gov', 'dot.state.tx.us', 'ftp.dot.state.tx.us'] );
#         ga('send', 'pageview');
#
#     </script>
# </link></head>
# <body class="tundra" onload="init()" onresize="GetBrowser2()">
# <form action="./" id="form1" method="post" name="form1">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="/wEPDwULLTIwMTAwOTUyODdkZMMFDHmEKPVgMOh36PFurM1un2/3QDc6O2fY0IMotBt0"/>
# <script src="/apps-cq/project_tracker/ScriptResource.axd?d=Ukm0pIHcx4ki6Vo1NrX_wQJBtO72lmcBuaLQ-mfw-SjS4v6o0VkQqr4N4qpDPQIzzUkdHAuQXbzy8yOp4BpflQnz9_KbFeBVbKpgFrM_m4JcUe_s-Rt_gWeFSubXx6ViXFM83ZabLo0zocLsZ61QCqDg1RPUMOrx21RKf9flx02vVtccltCgvKZS330pNJ4Z0&amp;t=363be08" type="text/javascript"></script>
# <script type="text/javascript">
# //<![CDATA[
# if (typeof(Sys) === 'undefined') throw new Error('ASP.NET Ajax client-side framework failed to load.');
# //]]>
# </script>
# <script src="js/singleWing.js" type="text/javascript"></script>
# <script src="js/functions.js" type="text/javascript"></script>
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="80DAFEB1"/>
# <div id="content">
# <div class="header_background_block" style="overflow:hidden">
# <div class="header_background">
# <a href="http://www.txdot.gov/">
# <!--<img alt="Texas Department of Transportation Logo" src="/apps-cg/_asset_collection/txdot_logo.png" width="584" height="94" style="border-width: 0px">-->
# <img alt="Texas Department of Transportation Logo" height="94" src="img/txdot_logo.png" style="border-width: 0px" width="584"/>
# </a>
# <!--        <div class="search_and_links_block">
#             <div class="headerarea_font site_index_and_spanish_block">
#                 <!--<a href="http://www.txdot.gov/inside-txdot/sitemap.html" style="color: #FFFFFF; text-decoration: none">A - Z Site Index</a> &nbsp;|&nbsp;
#                 <a href="http://www.txdot.gov/inside-txdot/contact-us.html" style="color: #FFFFFF; text-decoration: none">Contact Us</a> &nbsp;|&nbsp;
#                 <a href="http://www.txdot.gov/inside-txdot/spanish.html" style="color: #FFFFFF; text-decoration: none">Espa&ntilde;ol</a>-->
# </div>
# <div style="height:57px;"></div>--&gt;
#   </div>
# </div>
#
# <!--<script LANGUAGE="JavaScript" SRC="/apps-cg/_site_includes/pagecomponents/s_code.js" TYPE="text/javascript"></script>
# <script LANGUAGE="JavaScript" SRC="/apps-cg/_site_includes/pagecomponents/pagevariables.js" TYPE="text/javascript"></script>-->
# <img alt="" id="LoadingImg" src="img/Loading.gif" style="position:absolute; z-index:104; left: 500px; top: 335px; visibility: hidden;">
# <img alt="" id="LoadingImg2" src="img/download.png" style="position:absolute; z-index:104; left: 500px; top: 435px; visibility: hidden;"/>
# <div id="general">
# <div id="divptheader">
# <table style="border: none;">
# <tr class="altHeader">
# <td align="left" style="border: none; width: 10%; padding: 0px;">
# <img alt="Project Tracker" onclick="resetPage();" src="img/icons/pt-ribbon.png" style="position: relative; left: -1px; height:33px" title="Click to reset page"/>
# </td>
# <td align="Left" class="OtherModes tdNoBorder2" style="font-size: 15px; vertical-align: middle; width: auto;">
# <div style="padding-left: 1px;">
# <ul id="HelpNavigation1">
# <li class="sub"><a href="http://www.TxDOT.gov" target="_blank">TxDOT</a></li>
# <li style="color: #FFF; height: 27px; text-align: center;">| </li>
# <li style="color: #FFF;"> <a href="http://gis-txdot.opendata.arcgis.com/" target="_blank">Open Data Portal</a> </li>
# <li style="color: #FFF; height: 27px; text-align: center;">| </li>
# <li style="color: #FFF;"> <a href="http://www.txdot.gov/apps/statewide_mapping/StatewidePlanningMap.html" target="_blank">Statewide Planning Map</a> </li>
# </ul>
# </div>
# </td>
# <td class="ExportData">
# <ul id="navigation">
# <li><a href="http://www.txdot.gov/inside-txdot/projects/project-tracker.html" style="text-decoration: none;" target="_blank">About</a></li>
# <li style="color: #fff; height: 27px; text-align: center;">| </li>
# <li class="sub"><a href="#" style="text-decoration: none;">Help</a>
# <ul style="margin-bottom: 0px; padding-bottom: 0px;">
# <li class="sub"><a href="https://txdot.maps.arcgis.com/apps/Cascade/index.html?appid=a9c6a2a7ff7944c19ce532968db96dd8" style="text-decoration: none;" target="_blank">Interactive</a></li>
# <li class="sub"><a href="https://youtu.be/W_RmvKovYpQ" target="_blank">Tutorial</a></li>
# <li class="sub"><a href="mailto:Project.Tracker@txdot.gov">Contact Us</a></li>
# </ul>
# </li>
# <li style="color: #fff; height: 27px; text-align: center;">| </li>
# <li class="sub"><a href="#" style="text-decoration: none;">Export Data</a>
# <ul style="margin-bottom: 0px; padding-bottom: 0px;">
# <li class="sub"><a href="#" onclick="BuildFilteredReport('PDF');">PDF</a></li>
# <li class="sub"><a href="#" onclick="BuildFilteredReport('XLSX');">XLSX</a></li>
# <li style="padding-bottom: 0px;"><a href="ftp://ftp.dot.state.tx.us/pub/txdot-info/tpp/project-tracker/ProjectTracker.xml" target="_blank">XML</a></li>
# <li class="sub"><a href="#" onclick="Detailed_Export('SHP');"> ShapeFile</a></li>
# </ul>
# </li>
# </ul>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <div id="main">
# <div class="sidebar-offcanvas" id="sidebar">
# <div class="col-md-12 no-padding">
# <div id="filterOptions">
# <div "text-center"="" ,="" class="search_options">
# <div class="search_keyword">
# <h3>SEARCH by KEYWORD <img alt="Key Help" onclick="KeywordHelp()" src="img/Help.png" style="position: relative; left: 0px;" title="Keyword Help"/>
# </h3>
# <div id="search" style=" box-sizing:border-box"></div>
# </div>
# <div class="search_year" id="divSearchYear">
# <h3 class="letter-spaced">Est. Construction Begin Year</h3>
# <div class="row" id="searchByYear">
# <div class="col-lg-6">
# <input class="form-control search-from-year" data-date-format="yyyy" id="inputYearFromValue" name="SearchYearName" placeholder="From" type="text" value="2010"/>
# </div>
# <div class="col-lg-6">
# <input class="form-control search-to-year" data-date-format="yyyy" id="inputYearToValue" name="SearchYearName" placeholder="To" type="text" value="2045"/>
# </div>
# </div>
# </div>
# <div id="Advanced" style="display: none;">
# <h3 class="letter-spaced">PHASE</h3>
# <table style="border: none;">
# <tr class="altHeaderAdvanced">
# <td align="left" style="border: none; width: 10%; padding: 0px;">
# <label> <input checked="true" id="chkCS" name="phases" onclick="TogglePhase('chkCS');" type="checkbox" value="Construction underway or begins soon"> Construction underway or begins soon</input></label>
# </td>
# </tr>
# <tr class="altHeaderAdvanced">
# <td align="left" style="border: none; width: 10%; padding: 0px;">
# <label> <input checked="true" id="chkFC" name="phases" onclick="TogglePhase('chkFC');" type="checkbox" value="Construction begins within 4 years"> Construction begins within 4 years</input></label>
# </td>
# </tr>
# <tr class="altHeaderAdvanced">
# <td align="left" style="border: none; width: 10%; padding: 0px;">
# <label> <input checked="true" id="chkUD" name="phases" onclick="TogglePhase('chkUD');" type="checkbox" value="Construction begins in 5 to 10 years"/> Construction begins in 5 to 10 years</label>
# </td>
# </tr>
# <tr class="altHeaderAdvanced">
# <td align="left" style="border: none; width: 10%; padding: 0px;">
# <label> <input checked="true" id="chkLTP" name="phases" onclick="TogglePhase('chkLTP');" type="checkbox" value="Corridor Studies, construction 10+ years"/> Corridor Studies, construction 10+ years</label>
# </td>
# </tr>
# </table>
# <h3 class="letter-spaced">TYPE <small>(OPTIONAL)</small></h3>
# <table style="border: none;">
# <tr class="altHeaderAdvanced">
# <td align="left" style="border: none; width: 10%; padding: 0px;">
# <input id="chkAltTrans" name="phases" onclick="ToggleType('chkAltTrans');" type="checkbox" value="Alternative Transportation"/> <label for="chkAltTrans">Alternative Transportation</label>
# </td>
# </tr>
# <tr class="altHeaderAdvanced">
# <td align="left" style="border: none; width: 10%; padding: 0px;">
# <input id="chkBridge" name="phases" onclick="ToggleType('chkBridge');" type="checkbox" value="Bridge"/> <label for="chkBridge">Bridge</label>
# </td>
# </tr>
# <tr class="altHeaderAdvanced">
# <td align="left" style="border: none; width: 10%; padding: 0px;">
# <input id="chkMaintenance" name="phases" onclick="ToggleType('chkMaintenance');" type="checkbox" value="Roadway_Maintenance"/> <label for="chkMaintenance">Maintenance</label>
# </td>
# </tr>
# <tr class="altHeaderAdvanced">
# <td align="left" style="border: none; width: 10%; padding: 0px;">
# <input id="chkMiscellaneous" name="phases" onclick="ToggleType('chkMiscellaneous');" type="checkbox" value="Miscellaneous"/> <label for="chkMiscellaneous">Miscellaneous</label>
# </td>
# </tr>
# <tr class="altHeaderAdvanced">
# <td align="left" style="border: none; width: 10%; padding: 0px;">
# <input id="chkMobility" name="phases" onclick="ToggleType('chkMobility');" type="checkbox" value="Mobility"/> <label for="chkMobility">Mobility</label>
# </td>
# </tr>
# <tr class="altHeaderAdvanced">
# <td align="left" style="border: none; width: 10%; padding: 0px;">
# <input id="chkSafety" name="phases" onclick="ToggleType('chkSafety');" type="checkbox" value="Safety"/> <label for="chkSafety">Safety</label>
# </td>
# </tr>
# </table>
# <h3 class="letter-spaced">PROGRAM <small>(OPTIONAL)</small></h3>
# <table style="border: none;">
# <tr class="altHeaderAdvanced">
# <td align="left" style="border: none; width: 10%; padding: 0px;">
# <input id="chkTop100" name="phases" onclick="ToggleProgram('chkTop100');" type="checkbox" value="Top 100"/> <label for="chkTop100">Top 100 Most Congested</label>
# </td>
# </tr>
# <tr class="altHeaderAdvanced">
# <td align="left" style="border: none; width: 10%; padding: 0px;">
# <input id="chkFreight" name="phases" onclick="ToggleProgram('chkFreight');" type="checkbox" value="Freight"/> <label for="chkFreight">Freight</label>
# </td>
# </tr>
# <tr class="altHeaderAdvanced">
# <td align="left" style="border: none; width: 10%; padding: 0px;">
# <input id="chkTrunk" name="phases" onclick="ToggleProgram('chkTrunk');" type="checkbox" value="Trunk"/> <label for="chkTrunk">Trunk</label>
# </td>
# </tr>
# <tr class="altHeaderAdvanced">
# <td align="left" style="border: none; width: 10%; padding: 0px;">
# <input id="chkEnergySector" name="phases" onclick="ToggleProgram('chkEnergySector');" type="checkbox" value="Energy Sector"/> <label for="chkEnergySector">Energy Sector</label>
# </td>
# </tr>
# <tr class="altHeaderAdvanced">
# <td align="left" style="border: none; width: 10%; padding: 0px;">
# <input id="chkUTPApproved" name="phases" onclick="ToggleProgram('chkUTPApproved');" title="Projects listed in the current UTP" type="checkbox" value="UTP Approved"/> <label for="chkUTPApproved">Current UTP</label>
# </td>
# </tr>
# </table>
# </div> <!-- Advanced -->
# <div class="search_actions row">
# <div class="col-lg-6">
# <button class="btn letter-spaced button btn-md" onclick="resetPage(); return false;" style="background: #ca7c29;">RESET</button>
# </div>
# </div>
# <div class="center advancedSearch" id="SwitchSearch" style="display: block;">
# <i class="glyphicon glyphicon-transfer"></i> <a href="#" onclick="toggleDIV('Advanced'); return false;">Switch to Advanced search</a>
# </div>
# <div class="center advancedSearch" id="SwitchSearchAdvanced" style="display: none;">
# <i class="glyphicon glyphicon-transfer"></i> <a href="#" onclick="toggleDIV('Advanced'); return false;">Switch to Basic search</a>
# </div>
# </div><!-- .searchOptions -->
# <hr/>
# <div id="projectStatusOptions" style="display: block;">
# <div id="projectStatusNotice"></div>
# </div>
# <div class="projectStatusOptions-advanced" id="projectStatusOptionsAdvanced" style="display: none;">
# <h3 class="letter-spaced Advanced_Summarize">Summarize Results By:</h3>
# <select class="form-control" id="selSummarizeBy" onchange="getSystemStatsAdvanced()">
# <option value="status">Project Phase</option>
# <option value="district">District</option>
# <option value="year">Year</option>
# </select>
# <br/><br/>
# <div id="projectStatusNoticeAdvanced" style="display: none;"></div>
# </div>
# </div><!-- filterOptions -->
# </div>
# </div>
# <div id="map" style="position: relative;">
# <div id="SiteDownDiv" style="display: none; z-index:999;" title="This application">
# <br/>
# <p1><strong>Oooops.  Something went wrong.</strong></p1>
# <br/>
# <br/>
# <p2 style="font-size: .7em; line-height: 150%;">We apologize, but one of the servers that hosts our feature layers has gone down.</p2>
# <br/>
# <p2 style="font-size: .7em; line-height: 150%;">Please stay tuned while the problem is fixed.</p2>
# <br/>
# <br/>
# <button id="noThanks" onclick="CloseSurveyDiv()" style="padding: 5px 10px; position: relative; right: 7px;"> Close </button>
# <!-- <button id="takeSurvey" style="padding: 5px 10px; position: relative; left: 7px;"><strong> Take the Survey </strong></button> -->
# <br/>
# <br/>
# <form style="font-size: .7em; position: absolute; bottom: 15px; width: 93%;">
# <input id="doNotShow" name="opt-out" type="checkbox"/> Do not show this message again<br/>
# </form>
# </div>
# <div id="dialog" style="display: none; z-index:999;" title="This application is best viewed:">
# <hr/>
# <p>
# 		    1. From your desktop
# 		  </p>
# <p>
# 			 With Firefox or Chrome, Safari, Microsoft Edge or Internet Explorer 11 (or higher)
# 			 with compatibility mode turned off
# 		    </p>
# <p>
# 		      2. IPAD - IOS 10.3.3 or Higher
# 		    </p>
# <br/>
# <p>
# <b>For information on:</b>
# <hr/>
# </p>
# <p>
# 		      Highway road conditions, visit <a href="https://drivetexas.org" target="_blank">DriveTexas<sup>TM</sup></a>
# </p>
# <p>
# 		      How we're addressing congestion, visit <a href="http://www.dot.state.tx.us/texasclearlanes/" target="_blank">TexasClearLanes</a>
# </p>
# <button class="yes" name="yes" onclick="DisableStartPopUp()"> Never Show This Window Again</button>
# </div>
# <div class="btn-group btn-group-responsive" id="header2"> <!--style="z-index:999; position:absolute;"> -->
# <button class="btn btn-default" id="txdotMap" onclick="addTxDOT()" title="View the TxDOT Base Map" type="button">TxDOT</button>
# <button class="btn btn-default" id="streets" onclick="addStreets()" title="View ESRI Streets" type="button">
# 	    Streets</button>
# <button class="btn btn-default" id="imagery" onclick="addImagery()" title="View Satellite Imagery" type="button">Imagery</button>
# <button class="btn btn-default" id="googleMaps" onclick="openGoogleMaps()" title="Open Google Maps" type="button">Google Maps</button>
# </div><!-- header2-->
# <div class="HomeButton" id="HomeButton" role="presentation" style="display: block;" widgetid="HomeButton">
# <div class="homeContainer">
# <div class="home" data-dojo-attach-point="_homeNode" onclick="GoHome()" role="button" tabindex="0" title="Default extent"><span>Home</span></div>
# </div>
# </div>
# <div id="divHelp">
# <table style="border: none; height: 12px;">
# <tr>
# <td align="right" class="OtherModes tdNoBorder2" style="font-size: 15px; vertical-align: middle; width: auto;">
# <div style="padding-left: 1px;">
# <ul id="HelpNavigation">
# <li> <img alt="Public Transportation" class="HelpIcons" hspace="7" onclick="ShowPDF('Public')" src="img/publictransportation.png" title="Public Transportation"/></li>
# <li class="dropdown">
# <a href="#">
# <img alt="Rail" class="dropbtn, HelpIcons" hspace="5" src="img/Bridge.png" title="Major Transportation Projects"/>
# </a>
# <div class="dropdown-content">
# <a href="#" onclick="ShowPDF('Major')">Description</a>
# <a href="#" onclick="ShowCSJProject('025304146')">US 281</a>
# <a href="http://ftp.dot.state.tx.us/pub/txdot-info/spd/cda/sh99-hi/project-sheet.pdf" target="_blank">SH 99 Seg. H&amp;1</a>
# </div>
# </li>
# <li> <img alt="Rail" class="HelpIcons" hspace="7" onclick="ShowPDF('Rail')" src="img/rail.png" title="Rail"/></li>
# <li> <img alt="Maritime" class="HelpIcons" hspace="7" onclick="ShowPDF('Maritime')" src="img/maritime.png" title="Maritime"/></li>
# <li> <img alt="Aviation" class="HelpIcons" hspace="7" onclick="ShowPDF('Aviation')" src="img/aviation.png" title="Aviation"/></li>
# </ul>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <div class="legend" id="divLegend" title="Click to show help for Legend">
# <img alt="Project Legend" class="tppLegend" src="Image/PT_Legend_3.png"/>
# </div>
# </div> <!-- #map -->
# <div id="CPA_PE_Pop"> </div>
# </div> <!-- #main -->
# <div id="selectionResultsContainer">
# <div id="selectionResultsContainerWrapper">
# <div id="selectionResultsControl">
# <button aria-label="Close" class="close close-info" onclick="closeInfo(); return false;" type="button"><span aria-hidden="true">×</span></button>
# <div class="center text-center project-summary">
# <b>Project Summary</b>
# </div>
# <button class="btn-paging" onclick="previousSelected(); return false;">&lt; prev</button> <button class="btn-paging" onclick="nextSelected(); return false;">next &gt;</button> <span id="selectionCount"></span>
# <button class="button btn-close pull-right" onclick="closeInfo(); return false;">CLEAR</button><br/>
# </div>
# <div class="center text-center project-summary" id="ShowHide">
# <button class="buttonShowHide" onclick="Show_All_popup(); return false;">Show All</button>
# <button class="buttonShowHide" onclick="Hide_All_popup(); return false;">Hide All</button>
# </div>
# <div id="selectionResults">
# <p>Click a project on the map for detailed information.</p>
# </div>
# </div>
# </div><!-- #selectionResultsContainer -->
#  <!-- #content -->
# </img></form>
# </body>
# </html>

# %%
links
# Out:
# []

# %%
for i in links:
    print(i.text)
    print("\n")
